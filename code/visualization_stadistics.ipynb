# %% [markdown]
# # Imputación con media

# %% [markdown]
# ## Preparar librerias

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings

# %% [markdown]
# ## Leer datos originales

# %% [markdown]
# Hay que leer el dataset original para comparar los datos imputados con los reales

# %% [markdown]
# Temperatura

# %%
#warnings.filterwarnings('ignore', category=SyntaxWarning)  # Porque el \d de \data y \daily lo toma como un valor especial
dataframe_temperatura = pd.read_csv("..\data\daily-minimum-temperatures-in-me.csv", header=0, index_col=0, parse_dates=True)
serie_temperatura = dataframe_temperatura.squeeze('columns')
serie_temperatura = serie_temperatura.resample('D').mean()
serie_temperatura['1984-12-31'] = (serie_temperatura['1984-12-30'] + serie_temperatura['1985-01-01'])/2
serie_temperatura['1988-12-31'] = (serie_temperatura['1988-12-30'] + serie_temperatura['1989-01-01'])/2
serie_temperatura.head()
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\alaba\AppData\Local\Temp\ipykernel_12280\4279680061.py:2: SyntaxWarning: invalid escape sequence '\d'
#   dataframe_temperatura = pd.read_csv("..\data\daily-minimum-temperatures-in-me.csv", header=0, index_col=0, parse_dates=True)
# Date
# 1981-01-01    20.7
# 1981-01-02    17.9
# 1981-01-03    18.8
# 1981-01-04    14.6
# 1981-01-05    15.8
# Freq: D, Name: Daily minimum temperatures in Melbourne, Australia, 1981-1990, dtype: float64

# %%
serie_temperatura.tail()
# Out:
# Date
# 1990-12-27    14.0
# 1990-12-28    13.6
# 1990-12-29    13.5
# 1990-12-30    15.7
# 1990-12-31    13.0
# Freq: D, Name: Daily minimum temperatures in Melbourne, Australia, 1981-1990, dtype: float64

# %% [markdown]
# Cardiovascular

# %%
dataframe_cardiovascular = pd.read_csv("..\data\\ads_hour.csv", header=0, index_col=0, parse_dates=True)
serie_cardiovascular = dataframe_cardiovascular.squeeze('columns')
serie_cardiovascular = serie_cardiovascular.astype(float)
serie_cardiovascular.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\alaba\AppData\Local\Temp\ipykernel_12280\3747356855.py:1: SyntaxWarning: invalid escape sequence '\d'
#   dataframe_cardiovascular = pd.read_csv("..\data\\ads_hour.csv", header=0, index_col=0, parse_dates=True)
# C:\Users\alaba\AppData\Local\Temp\ipykernel_12280\3747356855.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   dataframe_cardiovascular = pd.read_csv("..\data\\ads_hour.csv", header=0, index_col=0, parse_dates=True)
# Date
# 2017-08-03 00:00:00    49136.0
# 2017-08-03 01:00:00    46450.0
# 2017-08-03 02:00:00    46355.0
# 2017-08-03 03:00:00    43748.0
# 2017-08-03 04:00:00    42281.0
# Name: ads, dtype: float64

# %%
serie_cardiovascular.tail()
# Out:
# Date
# 2017-10-28 16:00:00    111837.0
# 2017-10-28 17:00:00    119322.0
# 2017-10-28 18:00:00    124567.0
# 2017-10-28 19:00:00    125366.0
# 2017-10-28 20:00:00    126644.0
# Name: ads, dtype: float64

# %% [markdown]
# Manchas solares

# %%
dataframe_sunspots = pd.read_csv("..\data\monthly-sunspots.csv", header=0, index_col=0, parse_dates=True)
serie_sunspots = dataframe_sunspots.squeeze('columns')
serie_sunspots = serie_sunspots.resample('ME').mean() # Para los meses
serie_sunspots.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\alaba\AppData\Local\Temp\ipykernel_12280\1648495023.py:1: SyntaxWarning: invalid escape sequence '\d'
#   dataframe_sunspots = pd.read_csv("..\data\monthly-sunspots.csv", header=0, index_col=0, parse_dates=True)
# Month
# 1749-01-31    58.0
# 1749-02-28    62.6
# 1749-03-31    70.0
# 1749-04-30    55.7
# 1749-05-31    85.0
# Freq: ME, Name: Sunspots, dtype: float64

# %%
serie_sunspots.tail()
# Out:
# Month
# 1983-08-31    71.8
# 1983-09-30    50.3
# 1983-10-31    55.8
# 1983-11-30    33.3
# 1983-12-31    33.4
# Freq: ME, Name: Sunspots, dtype: float64

# %% [markdown]
# ## Valores estadisticos

# %%
serie_sunspots.describe()
# Out:
# count    2820.000000
# mean       51.265957
# std        43.448971
# min         0.000000
# 25%        15.700000
# 50%        42.000000
# 75%        74.925000
# max       253.800000
# Name: Sunspots, dtype: float64

# %%
serie_temperatura.describe()
# Out:
# count    3652.000000
# mean       11.179587
# std         4.071482
# min         0.000000
# 25%         8.300000
# 50%        11.000000
# 75%        14.000000
# max        26.300000
# Name: Daily minimum temperatures in Melbourne, Australia, 1981-1990, dtype: float64

# %%
serie_cardiovascular.describe()
# Out:
# count      2085.000000
# mean      66313.917506
# std       17733.787578
# min       19986.000000
# 25%       53403.000000
# 50%       65027.000000
# 75%       77112.000000
# max      126644.000000
# Name: ads, dtype: float64

# %% [markdown]
# ## Visualizacion

# %% [markdown]
# ### Temperatura

# %%
serie_temperatura.plot(figsize=(20, 12))
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20, 12))
ax.hist(serie_temperatura.values)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20, 12))
ax.boxplot(serie_temperatura.values)
plt.show()

# %% [markdown]
# ### Cardiovascular

# %%
serie_cardiovascular.plot(figsize=(20, 12))
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20, 12))
ax.hist(serie_cardiovascular.values)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20, 12))
ax.boxplot(serie_cardiovascular.values)
plt.show()

# %% [markdown]
# ### Manchas solares

# %%
serie_sunspots.plot(figsize=(20, 12))
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20, 12))
ax.hist(serie_sunspots.values)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20, 12))
ax.boxplot(serie_sunspots.values)
plt.show()

# %% [markdown]
# ## Retocar Cardiovascular

# %%
serie_cardiovascular['2017-08-24 00:00:00':'2017-08-27 00:00:00'].plot(figsize=(8, 8))
plt.show()
